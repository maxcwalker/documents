# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np
from sklearn import linear_model
from matplotlib import pyplot as plt

# %%
d = pd.read_excel("productRelationships.xlsx", sheet_name = 'Data')
d = d.drop(columns = "Client_Id")
d.head()
# Out:
#   Repurchase_Period First_Product_Category Subsequent_Product_Category  \
# 0     00 - 06 Month                ACC BAG                  ACC BOTTLE
# 1     00 - 06 Month                ACC BAG             ACC NOISE MAKER
# 2     00 - 06 Month             ACC BASKET            SCOOTER ELECTRIC
# 3     00 - 06 Month               ACC BELL               SPARES CLAMPS
# 4     00 - 06 Month               ACC BELL               SPARES WHEELS
#
#    Subsequent_Items_Ordered  Subsequent_Net_Value_before_Returns
# 0                         3                                22.38
# 1                         1                                 9.13
# 2                         1                               416.63
# 3                         2                                14.92
# 4                        13                               161.61

# %%
d.describe()
# Out:
#        Subsequent_Items_Ordered  Subsequent_Net_Value_before_Returns
# count              13097.000000                         13097.000000
# mean                  35.187982                           956.059792
# std                  279.900969                          7589.753437
# min                    1.000000                             0.010000
# 25%                    1.000000                            16.670000
# 50%                    3.000000                            74.960000
# 75%                   12.000000                           292.380000
# max                17393.000000                        474337.400000

# %%
# reading headers
d.columns
# Out:
# Index(['Repurchase_Period', 'First_Product_Category',
#        'Subsequent_Product_Category', 'Subsequent_Items_Ordered',
#        'Subsequent_Net_Value_before_Returns'],
#       dtype='object')

# %%
#read each column 
d[['Subsequent_Product_Category','Subsequent_Items_Ordered']]
# Out:
#       Subsequent_Product_Category  Subsequent_Items_Ordered
# 0                      ACC BOTTLE                         3
# 1                 ACC NOISE MAKER                         1
# 2                SCOOTER ELECTRIC                         1
# 3                   SPARES CLAMPS                         2
# 4                   SPARES WHEELS                        13
# ...                           ...                       ...
# 13092                ACC WINDMILL                         1
# 13093               SCOOTER ADULT                         4
# 13094                SCOOTER MAXI                         1
# 13095               SCOOTER ADULT                         1
# 13096                SPARES BRAKE                         3
#
# [13097 rows x 2 columns]

# %%
#reading a specific row
d.iloc[1]
# Out:
# Repurchase_Period                        00 - 06 Month
# First_Product_Category                         ACC BAG
# Subsequent_Product_Category            ACC NOISE MAKER
# Subsequent_Items_Ordered                             1
# Subsequent_Net_Value_before_Returns               9.13
# Name: 1, dtype: object

# %%
d.loc[d['Subsequent_Product_Category'] == "ACC BOTTLE HOLDER"]
# Out:
#       Repurchase_Period First_Product_Category Subsequent_Product_Category  \
# 27        00 - 06 Month     ACC PULL AND CARRY           ACC BOTTLE HOLDER
# 41        00 - 06 Month               ACC SETS           ACC BOTTLE HOLDER
# 93        00 - 06 Month        ACC SCOOTER PEG           ACC BOTTLE HOLDER
# 178       00 - 06 Month             ACC BASKET           ACC BOTTLE HOLDER
# 186       00 - 06 Month      ACC BOTTLE HOLDER           ACC BOTTLE HOLDER
# ...                 ...                    ...                         ...
# 12405     49 - 54 Month           SPARES BRAKE           ACC BOTTLE HOLDER
# 12560     49 - 54 Month         SCOOTER 3 IN 1           ACC BOTTLE HOLDER
# 12706     49 - 54 Month           SCOOTER MAXI           ACC BOTTLE HOLDER
# 12736     49 - 54 Month                BUNDLES           ACC BOTTLE HOLDER
# 12872     55 - 60 Month           SCOOTER MINI           ACC BOTTLE HOLDER
#
#        Subsequent_Items_Ordered  Subsequent_Net_Value_before_Returns
# 27                          116                               657.72
# 41                           35                               224.59
# 93                            1                                 4.96
# 178                           3                                11.79
# 186                          27                               139.71
# ...                         ...                                  ...
# 12405                         1                                 3.19
# 12560                         8                                41.41
# 12706                         1                                 3.58
# 12736                         1                                 3.83
# 12872                         5                                37.54
#
# [236 rows x 5 columns]

# %%
d2 = pd.read_excel('productRelationships.xlsx', sheet_name='Sheet1')
d2.head()
# Out:
#   First Product Category  ACC BAG  ACC BASKET  ACC BELL  ACC BOTTLE  \
# 0                ACC BAG     14.0         NaN      17.0         3.0
# 1             ACC BASKET     43.0        35.0      19.0         4.0
# 2               ACC BELL    273.0       535.0     140.0         NaN
# 3             ACC BOTTLE     38.0         5.0      20.0         1.0
# 4      ACC BOTTLE HOLDER     74.0        36.0     183.0       143.0
#
#    ACC BOTTLE HOLDER  ACC CARRY BAG  ACC FLOWER  ACC GLOVES  ACC HANDWARMERS  \
# 0                NaN            NaN         NaN         2.0              NaN
# 1                3.0            NaN         NaN         NaN              3.0
# 2                6.0            NaN         1.0         9.0              5.0
# 3                NaN            NaN         NaN         NaN              1.0
# 4               27.0            NaN         NaN         NaN              1.0
#
#    ...  SPARES WHEELS  SYSTEM  TRY BEFORE YOU BUY  VOUCHER  \
# 0  ...            1.0     1.0                 NaN      NaN
# 1  ...            5.0     8.0                 NaN      NaN
# 2  ...           13.0    13.0                 NaN      NaN
# 3  ...            NaN     1.0                 NaN      NaN
# 4  ...            1.0     3.0                 NaN      NaN
#
#    X CHILLI ACCESSORIES  X CHILLI SCOOTER ALL STAR  X CHILLI SCOOTER RIDERS  \
# 0                   NaN                        NaN                      NaN
# 1                   NaN                        NaN                      NaN
# 2                   NaN                        NaN                      NaN
# 3                   NaN                        NaN                      NaN
# 4                   NaN                        NaN                      NaN
#
#    X CHILLI SCOOTER YOUNGSTER  X CHILLI SPARES  Grand Total
# 0                         NaN              NaN          123
# 1                         NaN              NaN          275
# 2                         NaN              NaN         1335
# 3                         NaN              NaN           76
# 4                         NaN              NaN          532
#
# [5 rows x 78 columns]

# %%
import seaborn as sns
corr = d2.corr()
plt.figure(figsize=(20, 20))
sns.heatmap(corr, vmax=0.5, center=0,
            square=True, linewidths=2, cmap='Blues')
plt.savefig("heatmap.png")
# Out:
# /tmp/ipykernel_168942/693747998.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = d2.corr()

# %% [markdown]
# ### Lets try and categorise the table as this still doesn't show us much

# %% [markdown]
# d3 = d2.loc.groupby(d2['First Product Category'].str([0:3]))

# %% [markdown]
# d4 = d2.groupby(d2['First Product Category'], d2['First Product Category'].str([0:3]))

# %%
d3 = d2['First Product Category'].str.contains('ACC', case=False)
ACC = []

for i in range(len(d2)):
    if d3[i] == True:
    ACC.append(d2[i])

# %%
d3 = d2[d2['First Product Category'].str.contains('ACC')]

corr2 = d3.corr()
plt.figure(figsize=(20, 20))
sns.heatmap(corr2, vmax=0.5, center=0,
            square=True, linewidths=2, cmap='Blues')
# Out:
# /tmp/ipykernel_168942/338201481.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr2 = d3.corr()
# <AxesSubplot:>

# %%
acc = []
for i in range(len(d2)):
    if d2['First Product Category'].iloc[i].str.contains('ACC',case=False) == True:
        acc.append(d2.iloc[i])
acc
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [12], line 3
#       1 acc = []
#       2 for i in range(len(d2)):
# ----> 3     if d2['First Product Category'].iloc[i].str.contains('ACC',case=False) == True:
#       4         acc.append(d2.iloc[i])
#       5 acc
#
# AttributeError: 'str' object has no attribute 'str'

# %%
print(np.shape(d2))
print(np.shape(d3))
